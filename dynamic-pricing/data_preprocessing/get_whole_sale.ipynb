# %%
import pandas as pd
import urllib.request
from pprint import pprint
import json
import tqdm

# %%
#https://apis.data.go.kr/6260000/EgMarketCost/getDailyCost?serviceKey=7Ni6ien3TkEseiXPeAOmlFsKa0L9n%2F3%2Bw4ojTlWpTN9FpsSjrWLFVRv1Wt%2BW2MvnS5kvKYoBcoBV5VvQkv6nVw%3D%3D
#&pageNo=1
#&numOfRows=5
#&cmpName=항도청과(주)
#&goodName=표고버섯(일반)
#&midName=표고버섯
#&largeName=버섯류
#&resultType=json

def getData(pageNo, numOfRows=10000):
        
    encodingKey = "7Ni6ien3TkEseiXPeAOmlFsKa0L9n%2F3%2Bw4ojTlWpTN9FpsSjrWLFVRv1Wt%2BW2MvnS5kvKYoBcoBV5VvQkv6nVw%3D%3D"
    decodingKey = "7Ni6ien3TkEseiXPeAOmlFsKa0L9n/3+w4ojTlWpTN9FpsSjrWLFVRv1Wt+W2MvnS5kvKYoBcoBV5VvQkv6nVw=="
    
    url = f"http://apis.data.go.kr/6260000/EgMarketCost/getDailyCost?serviceKey={encodingKey}&resultType=json&numOfRows={numOfRows}&pageNo={pageNo}"
        
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request) # request보내기
    rescode = response.getcode() # 결과 코드 정의

    if(rescode==200):
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        pprint(data)
    else:
        print("Error Code:" + rescode)
    return data

# %%
df = pd.DataFrame(columns=list(items[0].keys()))
for i in range(1,10):
    data = getData(pageNo=i)
    items = data['getDailyCost']['body']['items']['item']
    for item in items:
        df = df.append(item, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df = pd.DataFrame(columns=list(items[0].keys()))
#       2 for i in range(1,10):
#       3     data = getData(pageNo=i)
#
# NameError: name 'items' is not defined

# %%
data = getData(pageNo=1)
items = data['getDailyCost']['body']['items']['item']
df = pd.DataFrame(columns=list(items[0].keys()))
for item in items:
    df = df.append(item, ignore_index=True)
# Out:
# /var/folders/0b/g18r48wj7ts0_vpj31996ms40000gn/T/ipykernel_96775/1902686350.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# /var/folders/0b/g18r48wj7ts0_vpj31996ms40000gn/T/ipykernel_96775/1902686350.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# /var/folders/0b/g18r48wj7ts0_vpj31996ms40000gn/T/ipykernel_96775/1902686350.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(item, ignore_index=True)
# /var/folders/0b/g18r48wj7ts0_vpj31996ms40000gn/T/ipykernel_96775/1902686350.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df.to_csv('whole_sale_price.csv', index=False, encoding='utf-8-sig')

# %%
len(good_name)
# Out:
# 241

# %%
good_name = df['goodName'].unique()
for i in range(0, len(good_name), 6):
    print(f'|{good_name[i]}|{good_name[i+1]}|{good_name[i+2]}|{good_name[i+3]}|{good_name[i+4]}|{good_name[i+5]}|')
# Out:
# |표고버섯(일반)|화고건표고|팽이1호|기타팽이버섯|양상추(일반)|치커리(일반)|
# |브로코리(일반)|브로코리(수입)|쌈케일|파프리카(일반)|취나물(일반)|참나물(일반)|
# |방풍나물(일반)|느타리버섯(일반)|기타느타리버섯|양송이(일반)|열무(일반)|시금치(일반)|
# |미나리(일반)|일반부추|깻잎(일반)|깻잎순|쑥갓(일반)|근대(일반)|
# |아욱(일반)|생고구마순|참비름|생머위대|생고추잎|생호박잎|
# |청경채(일반)|무순(일반)|쌈추|다발무|기타무|당근(일반)|
# |당근(수입)|우엉(일반)|만생양파|대파(일반)|대파(수입)|쪽파(일반)|
# |청양|오이맛고추|꽈리고추(일반)|홍고추(일반)|저장형 한지|마늘쫑(수입)|
# |방아(일반)|수박(일반)|노랑참외|토마토(일반)|네트계|방울토마토|
# |가시오이|노각|쥬키니호박|풋호박|단호박|가지(일반)|
# |박(일반)|쌈배추|기타배추|얼갈이배추|양배추(일반)|양배추(수입)|
# |청상추|적상추|적포기|기타|후지|아오리|
# |홍로|시나노스위트|기타사과|원황|캠벨얼리|거봉|
# |샤인마스캇|기타포도|백봉|황도|만가닥(일반)|새송이(일반)|
# |홍자두|추희|하우스감귤|무화과(일반)|아로니아(일반)|강낭콩(일반)|
# |찰옥수수|수미|자주감자|기타감자|붉은고구마|청포도|
# |유명|백도|천중도백도|털복숭아(일반)|경봉|홍청양|
# |햇마늘 대서|생강(일반)|청피망|적채(일반)|비트(일반)|칼리플라워(일반)|
# |노랑파프리카|빨강파프리카|오렌지파프리카|더덕(일반)|대지|기타고구마순|
# |총각무(일반)|연근(일반)|양파(일반)|아삭이|당조|모닝|
# |완숙토마토|파파야계|기타메론|대추방울|백다다기|애호박|
# |여주(일반)|기타상추|대왕|기타복숭아|백천황도|홍금향|
# |도담|기타자두|블루베리(일반)|수박(일반)(꼭지절단)|기타참외|산사|
# |하쯔쓰가루|행수|미백|레드골드|금도|아부백도|
# |네호네백도|천도|성백도|왕도|기타양상추|기타아스파라가스|
# ...

# %%
df
# Out:
#      midName  goodName  danq dan    poj sizeName  lv minCost maxCost aveCost  \
# 0       표고버섯  표고버섯(일반)  13.1  kg  P-BOX      11개   특   65500   77290   71400
# 1       표고버섯  표고버섯(일반)    16  kg  P-BOX      11개   특   68800   99200   84000
# 2       표고버섯  표고버섯(일반)  12.5  kg  P-BOX      11개   특   71250   72500   71700
# 3       표고버섯  표고버섯(일반)  13.9  kg  P-BOX      11개   특   73670   94520   81500
# 4       표고버섯  표고버섯(일반)  14.3  kg  P-BOX      11개   특   75790   75790   75800
# ...      ...       ...   ...  ..    ...      ...  ..     ...     ...     ...
# 5888    표고버섯  표고버섯(일반)  16.1  kg  P-BOX       없음  보통   42665  128800   92800
# 5889    표고버섯  표고버섯(일반)  15.8  kg  P-BOX       없음  보통   44240   44240   44200
# 5890    표고버섯  표고버섯(일반)  15.2  kg  P-BOX       없음  보통   48260   48260   48300
# 5891    표고버섯  표고버섯(일반)  14.4  kg  P-BOX       없음  보통   49680   59760   54700
# 5892    표고버섯  표고버섯(일반)  15.6  kg  P-BOX       없음  보통   56940   88920   72900
#
#         saledate  cmpName largeName
# ...

# %%
df1 = pd.read_csv('whole_sale_price_1.csv')
df2 = pd.read_csv('whole_sale_price_2.csv')

# %%
df_concat = pd.concat([df1, df2])

# %%
df_concat.to_csv('whole_sale_price.csv', index=False, encoding='utf-8-sig')
